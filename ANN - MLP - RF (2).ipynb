# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import cross_val_score, train_test_split
from sklearn.metrics import accuracy_score, classification_report, roc_auc_score, roc_curve
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import GridSearchCV

from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.neural_network import MLPClassifier


import tensorflow as tf
import kerastuner as kt
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.optimizers import legacy  # to run legacy adam optimiser
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.layers import Dropout

# %% [markdown]
# ### Data Import and Preprocessing

# %%
X = pd.read_csv('/Users/parvathyrajan/Desktop/Course Work - Traffic Sign DataSet/Complete Data Set - Training/x_train_all.csv')
y = pd.read_csv('/Users/parvathyrajan/Desktop/Course Work - Traffic Sign DataSet/Complete Data Set - Training/y_train_all.csv')

X_test_all = pd.read_csv('/Users/parvathyrajan/Desktop/Course Work - Traffic Sign DataSet/Complete Data Set - Test/x_test_all.csv')
y_test_all = pd.read_csv('/Users/parvathyrajan/Desktop/Course Work - Traffic Sign DataSet/Complete Data Set - Test/y_test_all.csv')

# %%
X.shape
#y.shape
# Out:
# (9690, 2304)

# %% [markdown]
# ### Random Forest Feature Selection Dataset

# %%
# Normalize the test and train dataset
X_normalized = X / 255
X_test_all_normalised =  X_test_all / 255

# Split the normalized data into training and validation sets
X_train, X_test, y_train, y_test = train_test_split(X_normalized, y, test_size=0.2, stratify=y, random_state=42)


if isinstance(y_train, pd.DataFrame):
    y_train = y_train.squeeze()  # Convert to Series if it's a DataFrame
elif isinstance(y_train, np.ndarray) and y_train.ndim == 2:
    y_train = y_train.ravel()  # Convert to 1D array if it's a 2D numpy array

# Train a Random Forest Classifier on the normalized training data
rf_model = RandomForestClassifier(random_state=42)
rf_model.fit(X_train, y_train)

# Extract feature importances from the trained model
importances_rf = rf_model.feature_importances_

# Sort the feature importances in descending order and get the indices of the top 150 features
indices_rf = np.argsort(importances_rf)[::-1][:150]

# If X_train and X_test are pandas DataFrames, use .iloc to select the top features
X_train_top_features = X_train.iloc[:, indices_rf]
X_test_top_features = X_test.iloc[:, indices_rf]

# If you want to apply this top feature selection to the entire dataset and it is a DataFrame:
X_reduced_rf = X_normalized.iloc[:, indices_rf]


# If you want to apply this top feature selection to the entire dataset and it is a DataFrame:
X_test_all_rf = X_test_all_normalised.iloc[:, indices_rf]

# %%
# Print to csv for check (for self)

X_reduced_rf.to_csv('X_train_reduced.csv', index=False)
X_test_all_rf.to_csv('X_test_reduced.csv', index=False)

# %%
output = "X_reduced_rf shape: {}, X_test_all_rf shape: {}, y_test_all shape: {}".format(X_reduced_rf.shape, X_test_all_rf.shape, y_test_all.shape)
print(output)
# Out:
# X_reduced_rf shape: (9690, 150), X_test_all_rf shape: (3090, 150), y_test_all shape: (3090, 1)

# %% [markdown]
# ## Test For Lineraly Separability - Logistics Regression

# %% [markdown]
# ### Linear Classifier Model Training - Using Train Test Split

# %%
#X_reduced_rf and X_test_all_rf are already normalised!

X_train, X_test, y_train, y_test = train_test_split(X_reduced_rf , y, test_size=0.2, stratify=y, random_state=42)

if isinstance(y_train, pd.DataFrame):
    y_train = y_train.squeeze()  # Convert to Series if it's a DataFrame
elif isinstance(y_train, np.ndarray) and y_train.ndim == 2:
    y_train = y_train.ravel()  # Convert to 1D array if it's a 2D numpy array

# Initialize the logistic regression classifier for multiclass classification

# The model didnot converge for values upto 1000 - So itertaion was increased to 1100 
#above which the warning for convergence didnot appear.

logistic_regression_classifier = LogisticRegression(multi_class='multinomial', solver='lbfgs', max_iter=1100, random_state=42)

# Train the classifier on the scaled training data
logistic_regression_classifier.fit(X_train, y_train)

# Predict the labels on the scaled test set
y_pred = logistic_regression_classifier.predict(X_test)

# Calculate the accuracy on the test set
test_accuracy = accuracy_score(y_test, y_pred)

print(f"Accuracy of the logistic regression classifier on the test set: {test_accuracy:.2f}")


# Predict the labels on the unseen test set
y_pred = logistic_regression_classifier.predict(X_test_all_rf)

# Calculate the accuracy on the unseen test set
test_accuracy = accuracy_score(y_test_all, y_pred)
print(f"Accuracy on unseen data: {test_accuracy:.2f}")
# Out:
# Accuracy of the logistic regression classifier on the test set: 0.93
# Accuracy on unseen data: 0.92

# %% [markdown]
# ### Linear Classifier Model Training - Using 10 Fold Cross Validation

# %%
#X_reduced_rf and X_test_all_rf are already normalised!

logistic_regression_classifier = LogisticRegression(multi_class='multinomial', solver='lbfgs', max_iter=1100, random_state=42)

# Perform 10-fold cross-validation
cv_scores = cross_val_score(logistic_regression_classifier, X_reduced_rf, y, cv=10)

# Fit the classifier to the training data
logistic_regression_classifier.fit(X_reduced_rf, y.values.ravel())

# Predict on the test set
y_pred = logistic_regression_classifier.predict(X_test_all_rf)

test_accuracy = accuracy_score(y_test_all, y_pred)

report = classification_report(y_test_all, y_pred)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.90      0.73      0.81        60
#            1       0.89      0.92      0.91       720
#            2       0.93      0.97      0.95       750
#            3       0.91      0.99      0.95       450
#            4       0.95      0.94      0.94       660
#            5       0.94      0.50      0.65        60
#            6       0.96      0.83      0.89        90
#            7       1.00      0.50      0.67        60
#            8       0.98      0.83      0.90       150
#            9       0.85      0.98      0.91        90
#
#     accuracy                           0.92      3090
#    macro avg       0.93      0.82      0.86      3090
# weighted avg       0.92      0.92      0.92      3090
# (array([0.86687307, 0.8998968 , 0.93188854, 0.92156863, 0.91124871,
#         0.91331269, 0.82352941, 0.91537668, 0.89060888, 0.92879257]),
#  0.9220064724919094)

# %%
# Calculating mean and standard deviation for the 10-fold cross-validation scores
cv_mean = cv_scores.mean()
cv_std = cv_scores.std()

# Plotting the 10-fold cross-validation accuracies
plt.figure(figsize=(10, 5))
plt.plot(range(1, 11), cv_scores, marker='o', linestyle='-', color='blue')
plt.title('10-fold Cross-validation Accuracies')
plt.xlabel('Fold Number')
plt.ylabel('Accuracy')
plt.ylim(0, 1)  # Assuming the accuracy is high, set the y-axis to start from 0.9 for better visualization
plt.xticks(range(1, 11))
plt.grid(True)

# Adding a horizontal line for the test accuracy
plt.axhline(y=test_accuracy, color='green', linestyle='--', label=f'Test Set Accuracy ({test_accuracy:.2f})')
plt.legend()

plt.show()

# Print the test set accuracy and mean CV accuracy
print(f"Test Set Accuracy: {test_accuracy:.2%}")

print(f"Mean CV Accuracy: {cv_mean:.2%}")
# Out:
# Test Set Accuracy: 92.20%
# Mean CV Accuracy: 90.03%

# %% [markdown]
# The average accuracy across the 10-fold cross-validation on the training set is approximately 90%
# The accuracy on the test set is 92%.
#
# These high accuracies suggest that the linear classifier is performing very well on both the training and the test data. This could indicate that the data set is likely linearly separable, meaning that a linear decision boundary is sufficient to separate the classes with high accuracy.
#
# The fact that the model's performance on the unseen test data is close to its performance on the training data also suggests that the model generalizes well to new data

# %% [markdown]
# ### Trying to draw a decioson boundry to clarify the above finding  - using just class 1 and class 2

# %%
#X_reduced_rf and X_test_all_rf are already normalised!

from sklearn.decomposition import PCA
from sklearn.linear_model import LogisticRegression

if isinstance(y, pd.DataFrame):
    y = y.squeeze()  # Convert to Series if it's a DataFrame
elif isinstance(y, np.ndarray) and y_train.ndim == 2:
    y = y.ravel()  # Convert to 1D array if it's a 2D numpy array

# Apply PCA and reduce to 2 dimensions
pca = PCA(n_components=2)
X_pca = pca.fit_transform(X_reduced_rf)

# Select only two classes (class 1 and class 2)
classes_to_keep = [1, 2]
idx = np.isin(y, classes_to_keep)
X_pca_filtered = X_pca[idx]
y_filtered = y[idx]

# Train the logistic regression model
clf = LogisticRegression(multi_class='multinomial', solver='lbfgs', max_iter=1100, random_state=42)

clf.fit(X_pca_filtered, y_filtered)

# Create a mesh to plot the decision boundary
x_min, x_max = X_pca_filtered[:, 0].min() - 1, X_pca_filtered[:, 0].max() + 1
y_min, y_max = X_pca_filtered[:, 1].min() - 1, X_pca_filtered[:, 1].max() + 1
h = 0.02  # Step size in the mesh
xx, yy = np.meshgrid(np.arange(x_min, x_max, h), np.arange(y_min, y_max, h))

# Predict class for each point in the mesh
Z = clf.predict(np.c_[xx.ravel(), yy.ravel()])
Z = Z.reshape(xx.shape)

# Plot the decision boundary
plt.figure(figsize=(8, 6))
plt.contourf(xx, yy, Z, alpha=0.8)

# Plot each class separately to add legends
for class_value in np.unique(y_filtered):
    plt.scatter(X_pca_filtered[y_filtered == class_value, 0],
                X_pca_filtered[y_filtered == class_value, 1],
                alpha=0.5,  # Adjust opacity here
                edgecolors='k',
                label=f'Class {class_value}')

plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.xlim(xx.min(), xx.max())
plt.ylim(yy.min(), yy.max())
plt.title('Decision Boundary in PCA-reduced Space')
plt.legend()  # This adds the legend
plt.show()

# %% [markdown]
# Conclusion:
# Visially looking at it the deciosn boundry isnt able to draw a clear line throught the data points of class1 and class2 though the data says otherwise.

# %% [markdown]
# ## MLP Using MLP classifier in Sklearn

# %%
#X_reduced_rf and X_test_all_rf are already normalised!


# Define the parameter grid to search for the best parameters

# Softmax is the default output activation function in MLP classifier.
param_grid = {
    'hidden_layer_sizes': [(150,), (200,), (150, 150), (200, 150), (150, 100)], #each ordered pair represents neurons in each layer
    'activation': ['tanh', 'relu'],
    'solver': ['sgd', 'adam'], # optomizers
    'alpha': [0.0001, 0.001, 0.01], # learning rate
    'learning_rate': ['constant', 'adaptive'],
}

# Initialize the MLPClassifier
#incraesing the iteration to get the model to converge was incraesing the computational time 

mlp = MLPClassifier(max_iter=100) 


# Initialize GridSearchCV to find the best parameters
grid_search = GridSearchCV(mlp, param_grid, n_jobs=-1, cv=3)

# Fit GridSearchCV using the scaled training data
grid_search.fit(X_reduced_rf, y)

# Print out the best parameters
print("Best parameters found: ", grid_search.best_params_)

# Evaluate the best model found by GridSearchCV on the test set
best_model = grid_search.best_estimator_
y_pred = best_model.predict(X_test_all_rf)
print(classification_report(y_test_all, y_pred))
# Out:
# /Users/parvathyrajan/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/parvathyrajan/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/parvathyrajan/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/parvathyrajan/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/parvathyrajan/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/parvathyrajan/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/parvathyrajan/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/parvathyrajan/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/parvathyrajan/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/parvathyrajan/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/parvathyrajan/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/parvathyrajan/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/parvathyrajan/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/parvathyrajan/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/parvathyrajan/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/parvathyrajan/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/parvathyrajan/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/parvathyrajan/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/parvathyrajan/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/parvathyrajan/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/parvathyrajan/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/parvathyrajan/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/parvathyrajan/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/parvathyrajan/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/parvathyrajan/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/parvathyrajan/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/parvathyrajan/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/parvathyrajan/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/parvathyrajan/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/parvathyrajan/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/parvathyrajan/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/parvathyrajan/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/parvathyrajan/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/parvathyrajan/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/parvathyrajan/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/parvathyrajan/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/parvathyrajan/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/parvathyrajan/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/parvathyrajan/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/parvathyrajan/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/parvathyrajan/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/parvathyrajan/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/parvathyrajan/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/parvathyrajan/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/parvathyrajan/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/parvathyrajan/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/parvathyrajan/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/parvathyrajan/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/parvathyrajan/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/parvathyrajan/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/parvathyrajan/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/parvathyrajan/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/parvathyrajan/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/parvathyrajan/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/parvathyrajan/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/parvathyrajan/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/parvathyrajan/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/parvathyrajan/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/parvathyrajan/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/parvathyrajan/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/parvathyrajan/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/parvathyrajan/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/parvathyrajan/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/parvathyrajan/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/parvathyrajan/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/parvathyrajan/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/parvathyrajan/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/parvathyrajan/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/parvathyrajan/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/parvathyrajan/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/parvathyrajan/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/parvathyrajan/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/parvathyrajan/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/parvathyrajan/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/parvathyrajan/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/parvathyrajan/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/parvathyrajan/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/parvathyrajan/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/parvathyrajan/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/parvathyrajan/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/parvathyrajan/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/parvathyrajan/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/parvathyrajan/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/parvathyrajan/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/parvathyrajan/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/parvathyrajan/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/parvathyrajan/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/parvathyrajan/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/parvathyrajan/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/parvathyrajan/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/parvathyrajan/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/parvathyrajan/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/parvathyrajan/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/parvathyrajan/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/parvathyrajan/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/parvathyrajan/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/parvathyrajan/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/parvathyrajan/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/parvathyrajan/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/parvathyrajan/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/parvathyrajan/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/parvathyrajan/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/parvathyrajan/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/parvathyrajan/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/parvathyrajan/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/parvathyrajan/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/parvathyrajan/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/parvathyrajan/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/parvathyrajan/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/parvathyrajan/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/parvathyrajan/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/parvathyrajan/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/parvathyrajan/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/parvathyrajan/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/parvathyrajan/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/parvathyrajan/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/parvathyrajan/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/parvathyrajan/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/parvathyrajan/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/parvathyrajan/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/parvathyrajan/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/parvathyrajan/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/parvathyrajan/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/parvathyrajan/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/parvathyrajan/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/parvathyrajan/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/parvathyrajan/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/parvathyrajan/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/parvathyrajan/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/parvathyrajan/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/parvathyrajan/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/parvathyrajan/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/parvathyrajan/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/parvathyrajan/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/parvathyrajan/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/parvathyrajan/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/parvathyrajan/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/parvathyrajan/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/parvathyrajan/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/parvathyrajan/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/parvathyrajan/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/parvathyrajan/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/parvathyrajan/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/parvathyrajan/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/parvathyrajan/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/parvathyrajan/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/parvathyrajan/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/parvathyrajan/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/parvathyrajan/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/parvathyrajan/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/parvathyrajan/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/parvathyrajan/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/parvathyrajan/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/parvathyrajan/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/parvathyrajan/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/parvathyrajan/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/parvathyrajan/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/parvathyrajan/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/parvathyrajan/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/parvathyrajan/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/parvathyrajan/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/parvathyrajan/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/parvathyrajan/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/parvathyrajan/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/parvathyrajan/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/parvathyrajan/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/parvathyrajan/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/parvathyrajan/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/parvathyrajan/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/parvathyrajan/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/parvathyrajan/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/parvathyrajan/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/parvathyrajan/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/parvathyrajan/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/parvathyrajan/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/parvathyrajan/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/parvathyrajan/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/parvathyrajan/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/parvathyrajan/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/parvathyrajan/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/parvathyrajan/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/parvathyrajan/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/parvathyrajan/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/parvathyrajan/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/parvathyrajan/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/parvathyrajan/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/parvathyrajan/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/parvathyrajan/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/parvathyrajan/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/parvathyrajan/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/parvathyrajan/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/parvathyrajan/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# ...
#   warnings.warn(
# /Users/parvathyrajan/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/parvathyrajan/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/parvathyrajan/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/parvathyrajan/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/parvathyrajan/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/parvathyrajan/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/parvathyrajan/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/parvathyrajan/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/parvathyrajan/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/parvathyrajan/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/parvathyrajan/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/parvathyrajan/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/parvathyrajan/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/parvathyrajan/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/parvathyrajan/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/parvathyrajan/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/parvathyrajan/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/parvathyrajan/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/parvathyrajan/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/parvathyrajan/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/parvathyrajan/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/parvathyrajan/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/parvathyrajan/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/parvathyrajan/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/parvathyrajan/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/parvathyrajan/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/parvathyrajan/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/parvathyrajan/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/parvathyrajan/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/parvathyrajan/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/parvathyrajan/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/parvathyrajan/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/parvathyrajan/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/parvathyrajan/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/parvathyrajan/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/parvathyrajan/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/parvathyrajan/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/parvathyrajan/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/parvathyrajan/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/parvathyrajan/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/parvathyrajan/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/parvathyrajan/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/parvathyrajan/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/parvathyrajan/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/parvathyrajan/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/parvathyrajan/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/parvathyrajan/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/parvathyrajan/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/parvathyrajan/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/parvathyrajan/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/parvathyrajan/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/parvathyrajan/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/parvathyrajan/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/parvathyrajan/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/parvathyrajan/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/parvathyrajan/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/parvathyrajan/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/parvathyrajan/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/parvathyrajan/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Best parameters found:  {'activation': 'tanh', 'alpha': 0.01, 'hidden_layer_sizes': (150, 150), 'learning_rate': 'constant', 'solver': 'adam'}
#               precision    recall  f1-score   support
#
#            0       0.89      0.93      0.91        60
#            1       0.92      0.97      0.94       720
#            2       0.97      0.98      0.97       750
#            3       0.97      0.99      0.98       450
#            4       0.98      0.94      0.96       660
#            5       0.91      1.00      0.95        60
#            6       0.97      0.87      0.92        90
#            7       1.00      0.50      0.67        60
#            8       0.88      0.93      0.91       150
#            9       0.91      0.80      0.85        90
#
#     accuracy                           0.95      3090
#    macro avg       0.94      0.89      0.91      3090
# weighted avg       0.95      0.95      0.95      3090
# /Users/parvathyrajan/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(

# %%
# Print out the best parameters
print("Best parameters found: ", grid_search.best_params_)

# Evaluate the best model found by GridSearchCV on the test set
best_model = grid_search.best_estimator_
y_pred = best_model.predict(X_test_all_rf)
print(classification_report(y_test_all, y_pred))
# Out:
# Best parameters found:  {'activation': 'tanh', 'alpha': 0.01, 'hidden_layer_sizes': (150, 150), 'learning_rate': 'constant', 'solver': 'adam'}
#               precision    recall  f1-score   support
#
#            0       0.89      0.93      0.91        60
#            1       0.92      0.97      0.94       720
#            2       0.97      0.98      0.97       750
#            3       0.97      0.99      0.98       450
#            4       0.98      0.94      0.96       660
#            5       0.91      1.00      0.95        60
#            6       0.97      0.87      0.92        90
#            7       1.00      0.50      0.67        60
#            8       0.88      0.93      0.91       150
#            9       0.91      0.80      0.85        90
#
#     accuracy                           0.95      3090
#    macro avg       0.94      0.89      0.91      3090
# weighted avg       0.95      0.95      0.95      3090

# %% [markdown]
# Incraesing the number of iteration to get the model to converge and also experimenting with different combination of neurons was computionally exhaustive using Gridsearch and MLP classifier in Sklearn. It wasnt effective for the comoplex dataset we have.
#
# Hence we decided to implement Tensor flow.The Keras Tuner tends to be more efficient than Grid Search for complex models and large hyperparameter spaces due to its smarter search algorithms and early-stopping capabilities.

# %% [markdown]
# ## MLP Using Tensor Flow

# %%
#!conda install tensorflow -y

# %% [markdown]
# ### Using Keras Tuner - To Find the Best Hyperparameter Set

# %%
#pip install keras-tuner

# %% [markdown]
# #### Hyerparameter Tuning

# %%
# Split your data
X_train_rf, X_test_rf, y_train_rf, y_test_rf = train_test_split(
    X_reduced_rf, y, test_size=0.2, stratify=y, random_state=42)

# One hot encode the dataset
y_train_rf = to_categorical(y_train_rf, num_classes=10)
y_test_rf = to_categorical(y_test_rf, num_classes=10)

n_features = X_train_rf.shape[1]



def build_model(hp):
    model = Sequential()
    # Tunable first hidden layer with variable activation function
    model.add(Dense(units=hp.Int('units', min_value=n_features, max_value=n_features*2, step=n_features//2),
                    activation=hp.Choice('activation', values=['relu', 'tanh', 'sigmoid']),
                    input_shape=(n_features,)))
    for i in range(hp.Int('num_layers', 1, 3)):  # Adding 1-3 hidden layers
        model.add(Dense(units=hp.Int(f'units_{i}', min_value=32, max_value=512, step=32),
                        activation=hp.Choice(f'activation_{i}', values=['relu', 'tanh', 'sigmoid'])))
    model.add(Dense(10, activation='softmax'))  # Output layer with 10 units for 10 classes
    model.compile(optimizer=legacy.Adam(hp.Float('learning_rate', min_value=1e-4, max_value=1e-2, sampling='LOG')),
                  loss='categorical_crossentropy',
                  metrics=['accuracy'])
    return model



# Initialize the tuner
tuner = kt.Hyperband(build_model,
                     objective='val_accuracy',
                     max_epochs=10,
                     factor=3,
                     directory='my_dir',
                     project_name='intro_to_kt')

# Perform the hyperparameter search
tuner.search(X_train_rf, y_train_rf,
             epochs=30,
             validation_data=(X_test_rf, y_test_rf))

# Get the optimal hyperparameters
best_hps = tuner.get_best_hyperparameters(num_trials=1)[0]



# Get the optimal hyperparameters
best_hps = tuner.get_best_hyperparameters(num_trials=1)[0]



# Build the model with the best hp
model = build_model(best_hps)

# Train the model
history = model.fit(X_train_rf, y_train_rf, epochs=30, validation_data=(X_test_rf, y_test_rf))
# Out:
# Reloading Tuner from my_dir/intro_to_kt/tuner0.json
# Epoch 1/30
# 243/243 [==============================] - 1s 1ms/step - loss: 1.0894 - accuracy: 0.6622 - val_loss: 0.7095 - val_accuracy: 0.7817
# Epoch 2/30
# 243/243 [==============================] - 0s 1ms/step - loss: 0.4958 - accuracy: 0.8532 - val_loss: 0.5276 - val_accuracy: 0.8297
# Epoch 3/30
# 243/243 [==============================] - 0s 1ms/step - loss: 0.3695 - accuracy: 0.8882 - val_loss: 0.2901 - val_accuracy: 0.9076
# Epoch 4/30
# 243/243 [==============================] - 0s 974us/step - loss: 0.2972 - accuracy: 0.9045 - val_loss: 0.2412 - val_accuracy: 0.9288
# Epoch 5/30
# 243/243 [==============================] - 0s 967us/step - loss: 0.2612 - accuracy: 0.9162 - val_loss: 0.2120 - val_accuracy: 0.9303
# Epoch 6/30
# 243/243 [==============================] - 0s 998us/step - loss: 0.2220 - accuracy: 0.9280 - val_loss: 0.2796 - val_accuracy: 0.9102
# Epoch 7/30
# 243/243 [==============================] - 0s 983us/step - loss: 0.1942 - accuracy: 0.9365 - val_loss: 0.1885 - val_accuracy: 0.9376
# Epoch 8/30
# 243/243 [==============================] - 0s 1ms/step - loss: 0.2039 - accuracy: 0.9283 - val_loss: 0.1805 - val_accuracy: 0.9365
# Epoch 9/30
# 243/243 [==============================] - 0s 988us/step - loss: 0.1579 - accuracy: 0.9489 - val_loss: 0.1793 - val_accuracy: 0.9448
# Epoch 10/30
# 243/243 [==============================] - 0s 967us/step - loss: 0.1633 - accuracy: 0.9461 - val_loss: 0.1617 - val_accuracy: 0.9453
# Epoch 11/30
# 243/243 [==============================] - 0s 971us/step - loss: 0.1423 - accuracy: 0.9523 - val_loss: 0.2222 - val_accuracy: 0.9319
# Epoch 12/30
# 243/243 [==============================] - 0s 957us/step - loss: 0.1285 - accuracy: 0.9577 - val_loss: 0.1018 - val_accuracy: 0.9727
# Epoch 13/30
# 243/243 [==============================] - 0s 950us/step - loss: 0.1213 - accuracy: 0.9576 - val_loss: 0.1317 - val_accuracy: 0.9567
# Epoch 14/30
# 243/243 [==============================] - 0s 955us/step - loss: 0.1135 - accuracy: 0.9601 - val_loss: 0.1328 - val_accuracy: 0.9623
# Epoch 15/30
# 243/243 [==============================] - 0s 956us/step - loss: 0.1137 - accuracy: 0.9600 - val_loss: 0.1189 - val_accuracy: 0.9608
# Epoch 16/30
# 243/243 [==============================] - 0s 968us/step - loss: 0.1204 - accuracy: 0.9591 - val_loss: 0.1194 - val_accuracy: 0.9572
# Epoch 17/30
# 243/243 [==============================] - 0s 966us/step - loss: 0.1048 - accuracy: 0.9635 - val_loss: 0.1756 - val_accuracy: 0.9412
# Epoch 18/30
# 243/243 [==============================] - 0s 945us/step - loss: 0.1032 - accuracy: 0.9643 - val_loss: 0.1087 - val_accuracy: 0.9690
# Epoch 19/30
# 243/243 [==============================] - 0s 973us/step - loss: 0.0841 - accuracy: 0.9720 - val_loss: 0.0871 - val_accuracy: 0.9732
# Epoch 20/30
# 243/243 [==============================] - 0s 976us/step - loss: 0.0874 - accuracy: 0.9712 - val_loss: 0.1053 - val_accuracy: 0.9690
# Epoch 21/30
# 243/243 [==============================] - 0s 962us/step - loss: 0.0870 - accuracy: 0.9723 - val_loss: 0.0921 - val_accuracy: 0.9737
# Epoch 22/30
# 243/243 [==============================] - 0s 976us/step - loss: 0.0770 - accuracy: 0.9733 - val_loss: 0.0799 - val_accuracy: 0.9747
# Epoch 23/30
# 243/243 [==============================] - 0s 972us/step - loss: 0.0873 - accuracy: 0.9687 - val_loss: 0.1220 - val_accuracy: 0.9608
# Epoch 24/30
# 243/243 [==============================] - 0s 967us/step - loss: 0.0859 - accuracy: 0.9724 - val_loss: 0.1121 - val_accuracy: 0.9644
# Epoch 25/30
# 243/243 [==============================] - 0s 1ms/step - loss: 0.0670 - accuracy: 0.9764 - val_loss: 0.1249 - val_accuracy: 0.9598
# Epoch 26/30
# 243/243 [==============================] - 0s 988us/step - loss: 0.0773 - accuracy: 0.9741 - val_loss: 0.1094 - val_accuracy: 0.9690
# Epoch 27/30
# 243/243 [==============================] - 0s 974us/step - loss: 0.0711 - accuracy: 0.9755 - val_loss: 0.0910 - val_accuracy: 0.9716
# Epoch 28/30
# 243/243 [==============================] - 0s 974us/step - loss: 0.0653 - accuracy: 0.9778 - val_loss: 0.0834 - val_accuracy: 0.9727
# Epoch 29/30
# 243/243 [==============================] - 0s 981us/step - loss: 0.0696 - accuracy: 0.9767 - val_loss: 0.1166 - val_accuracy: 0.9644
# Epoch 30/30
# 243/243 [==============================] - 0s 989us/step - loss: 0.0518 - accuracy: 0.9818 - val_loss: 0.0691 - val_accuracy: 0.9768

# %%
# Get the optimal hyperparameters
best_hps = tuner.get_best_hyperparameters(num_trials=1)[0]

# Print the best hyperparameters
print(f"The best number of units in the first densely-connected layer: {best_hps.get('units')}")
for i in range(best_hps.get('num_layers')):
    print(f"The best number of units in the densely-connected layer {i+1}: {best_hps.get(f'units_{i}')}")
print(f"The best learning rate for the optimizer: {best_hps.get('learning_rate')}")
print(f"The best learning rate for the optimizer: {best_hps.get('activation')}")
# Out:
# The best number of units in the first densely-connected layer: 300
# The best number of units in the densely-connected layer 1: 256
# The best number of units in the densely-connected layer 2: 32
# The best learning rate for the optimizer: 0.0016124465281378271
# The best learning rate for the optimizer: relu

# %%
# Access the history.history dictionary to get the loss values
training_loss = history.history['loss']
validation_loss = history.history['val_loss']

# Create a count of the number of epochs and use it as the x-axis
epochs = range(1, len(training_loss) + 1)

# Plotting the training and validation loss
plt.plot(epochs, training_loss, 'bo-', label='Training Loss')
plt.plot(epochs, validation_loss, 'ro-', label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.show()

# %% [markdown]
# ### Using the Optimal Hyper - Parameters from above test with Early Stopping

# %%
X_train_rf, X_test_rf, y_train_rf, y_test_rf = train_test_split(X_reduced_rf, y, test_size=0.2, stratify=y, random_state=42)

#One hot encode the dataset
y_train_rf = to_categorical(y_train_rf.values.ravel(), num_classes=10)
y_test_rf = to_categorical(y_test_rf.values.ravel(), num_classes=10)

n_features = X_train_rf.shape[1]



# Define the MLP model architecture
model = Sequential()
model.add(Dense(units= 300, activation='relu'))  
model.add(Dense(units= 256, activation='relu'))
model.add(Dense(units= 32, activation='relu'))
model.add(Dense(10, activation='softmax')) # Output layer with 10 units for 10 classes and softmax activation


model.compile(optimizer=legacy.Adam(learning_rate=0.001),
              loss='categorical_crossentropy',
              metrics=['accuracy'])




# Set up the early stopping callback
early_stopping = EarlyStopping(
    monitor='val_loss',  # Monitor the validation loss
    patience=5,          # Number of epochs with no improvement after which training will be stopped
    verbose=1,
    restore_best_weights=True  # Restores model weights from the epoch with the best value of the monitored quantity
)

# Add the callback to the fit function
history = model.fit(
    X_train_rf, y_train_rf, 
    epochs=50, 
    validation_data=(X_test_rf, y_test_rf),
    callbacks=[early_stopping]
)
# Out:
# Epoch 1/50
# 243/243 [==============================] - 0s 1ms/step - loss: 1.1502 - accuracy: 0.6357 - val_loss: 0.6591 - val_accuracy: 0.7833
# Epoch 2/50
# 243/243 [==============================] - 0s 1ms/step - loss: 0.5439 - accuracy: 0.8337 - val_loss: 0.4258 - val_accuracy: 0.8824
# Epoch 3/50
# 243/243 [==============================] - 0s 960us/step - loss: 0.3814 - accuracy: 0.8887 - val_loss: 0.3556 - val_accuracy: 0.8927
# Epoch 4/50
# 243/243 [==============================] - 0s 968us/step - loss: 0.3243 - accuracy: 0.8976 - val_loss: 0.2982 - val_accuracy: 0.8983
# Epoch 5/50
# 243/243 [==============================] - 0s 971us/step - loss: 0.2755 - accuracy: 0.9167 - val_loss: 0.2601 - val_accuracy: 0.9252
# Epoch 6/50
# 243/243 [==============================] - 0s 970us/step - loss: 0.2314 - accuracy: 0.9301 - val_loss: 0.2136 - val_accuracy: 0.9303
# Epoch 7/50
# 243/243 [==============================] - 0s 939us/step - loss: 0.2041 - accuracy: 0.9343 - val_loss: 0.1697 - val_accuracy: 0.9505
# Epoch 8/50
# 243/243 [==============================] - 0s 963us/step - loss: 0.1838 - accuracy: 0.9395 - val_loss: 0.1562 - val_accuracy: 0.9582
# Epoch 9/50
# 243/243 [==============================] - 0s 975us/step - loss: 0.1808 - accuracy: 0.9399 - val_loss: 0.1660 - val_accuracy: 0.9463
# Epoch 10/50
# 243/243 [==============================] - 0s 978us/step - loss: 0.1624 - accuracy: 0.9453 - val_loss: 0.1272 - val_accuracy: 0.9623
# Epoch 11/50
# 243/243 [==============================] - 0s 963us/step - loss: 0.1464 - accuracy: 0.9525 - val_loss: 0.1474 - val_accuracy: 0.9541
# Epoch 12/50
# 243/243 [==============================] - 0s 963us/step - loss: 0.1264 - accuracy: 0.9582 - val_loss: 0.1224 - val_accuracy: 0.9670
# Epoch 13/50
# 243/243 [==============================] - 0s 957us/step - loss: 0.1210 - accuracy: 0.9607 - val_loss: 0.1403 - val_accuracy: 0.9536
# Epoch 14/50
# 243/243 [==============================] - 0s 963us/step - loss: 0.1121 - accuracy: 0.9617 - val_loss: 0.1355 - val_accuracy: 0.9623
# Epoch 15/50
# 243/243 [==============================] - 0s 970us/step - loss: 0.1047 - accuracy: 0.9658 - val_loss: 0.1425 - val_accuracy: 0.9520
# Epoch 16/50
# 243/243 [==============================] - 0s 978us/step - loss: 0.0944 - accuracy: 0.9697 - val_loss: 0.0988 - val_accuracy: 0.9711
# Epoch 17/50
# 243/243 [==============================] - 0s 1ms/step - loss: 0.1003 - accuracy: 0.9657 - val_loss: 0.1405 - val_accuracy: 0.9572
# Epoch 18/50
# 243/243 [==============================] - 0s 974us/step - loss: 0.0958 - accuracy: 0.9703 - val_loss: 0.1024 - val_accuracy: 0.9701
# Epoch 19/50
# 243/243 [==============================] - 0s 970us/step - loss: 0.0834 - accuracy: 0.9717 - val_loss: 0.1383 - val_accuracy: 0.9541
# Epoch 20/50
# 243/243 [==============================] - 0s 979us/step - loss: 0.0823 - accuracy: 0.9721 - val_loss: 0.1655 - val_accuracy: 0.9484
# Epoch 21/50
# 243/243 [==============================] - 0s 973us/step - loss: 0.0748 - accuracy: 0.9742 - val_loss: 0.0840 - val_accuracy: 0.9747
# Epoch 22/50
# 243/243 [==============================] - 0s 1ms/step - loss: 0.0687 - accuracy: 0.9767 - val_loss: 0.1241 - val_accuracy: 0.9541
# Epoch 23/50
# 243/243 [==============================] - 0s 977us/step - loss: 0.0826 - accuracy: 0.9710 - val_loss: 0.1427 - val_accuracy: 0.9541
# Epoch 24/50
# 243/243 [==============================] - 0s 985us/step - loss: 0.0763 - accuracy: 0.9750 - val_loss: 0.0925 - val_accuracy: 0.9685
# Epoch 25/50
# 243/243 [==============================] - 0s 1ms/step - loss: 0.0654 - accuracy: 0.9781 - val_loss: 0.1136 - val_accuracy: 0.9670
# Epoch 26/50
# 228/243 [===========================>..] - ETA: 0s - loss: 0.0647 - accuracy: 0.9783Restoring model weights from the end of the best epoch: 21.
# 243/243 [==============================] - 0s 1ms/step - loss: 0.0638 - accuracy: 0.9788 - val_loss: 0.0993 - val_accuracy: 0.9685
# Epoch 26: early stopping

# %%
# Preprocess y_test_all if necessary
y_test_all_encoded = to_categorical(y_test_all.values.ravel(), num_classes=10)

# Evaluate the model
loss, accuracy = model.evaluate(X_test_all_rf, y_test_all_encoded)
print(f"Test Loss: {loss}")
print(f"Test Accuracy: {accuracy}")
# Out:
# 97/97 [==============================] - 0s 445us/step - loss: 0.4306 - accuracy: 0.9570
# Test Loss: 0.4305572807788849
# Test Accuracy: 0.9569579362869263

# %%
# Make predictions on the test set
y_pred_probabilities = model.predict(X_test_all_rf)

# Convert probabilities to class labels
y_pred_labels = np.argmax(y_pred_probabilities, axis=1)

# Generate the classification report

report = classification_report(y_test_all, y_pred_labels, target_names=['Class 1', 'Class 2', 'Class 3','Class 4'
                                                                        ,'Class 5','Class 6','Class 7', 'Class 8'
                                                                       ,'Class 9','Class 10'])
print(report)
# Out:
# 97/97 [==============================] - 0s 390us/step
#               precision    recall  f1-score   support
#
#      Class 1       0.93      0.95      0.94        60
#      Class 2       0.89      0.99      0.94       720
#      Class 3       0.99      0.96      0.98       750
#      Class 4       0.98      0.99      0.99       450
#      Class 5       1.00      0.93      0.96       660
#      Class 6       1.00      1.00      1.00        60
#      Class 7       0.95      0.92      0.94        90
#      Class 8       1.00      0.50      0.67        60
#      Class 9       0.95      0.95      0.95       150
#     Class 10       0.93      0.93      0.93        90
#
#     accuracy                           0.96      3090
#    macro avg       0.96      0.91      0.93      3090
# weighted avg       0.96      0.96      0.96      3090

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(acc) + 1)

# Plot training & validation accuracy
plt.plot(epochs, acc, 'bo', label='Training acc')
plt.plot(epochs, val_acc, 'b', label='Validation acc')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.figure()

# Plot training & validation loss
plt.plot(epochs, loss, 'bo', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.show()

# %% [markdown]
# Training and Validation Accuracy:
# The accuracy graph shows that the model's training accuracy improves rapidly and then plateaus
# The validation accuracy also improves and follows the training accuracy closely indicating that the model is generalizing well to the unseen data.
#
# Training and Validation Loss:
# The loss graph shows a rapid decrease in training loss which then stabalises with more epochs which means the model is learning better with increasing epochs.
# The validation loss decreases alongside the training loss and remains close in value, which also suggests that the model is generalizing well.

# %% [markdown]
# ### Trying Dropout Decreased the test accuracy of the model

# %%
X_train_rf, X_test_rf, y_train_rf, y_test_rf = train_test_split(X_reduced_rf, y, test_size=0.2, stratify=y, random_state=42)

#One hot encode the dataset
y_train_rf = to_categorical(y_train_rf.values.ravel(), num_classes=10)
y_test_rf = to_categorical(y_test_rf.values.ravel(), num_classes=10)

n_features = X_train_rf.shape[1]



#Define the MLP model architecture
model = Sequential()
model.add(Dense(units=300, activation='relu'))
model.add(Dropout(0.5))  # Dropout layer with 50% dropout rate

model.add(Dense(units=256, activation='relu'))
model.add(Dropout(0.5))  # Another dropout layer

model.add(Dense(units=32, activation='relu'))
model.add(Dropout(0.5))  # Another dropout layer



model.add(Dense(10, activation='softmax'))

model.compile(optimizer=legacy.Adam(learning_rate=0.001),
              loss='categorical_crossentropy',
              metrics=['accuracy'])


history = model.fit(X_train_rf, y_train_rf, epochs=50, validation_data=(X_test_rf, y_test_rf))
# Out:
# Epoch 1/50
# 243/243 [==============================] - 0s 1ms/step - loss: 1.8128 - accuracy: 0.3255 - val_loss: 1.1129 - val_accuracy: 0.6832
# Epoch 2/50
# 243/243 [==============================] - 0s 1ms/step - loss: 1.1829 - accuracy: 0.6103 - val_loss: 0.7392 - val_accuracy: 0.7833
# Epoch 3/50
# 243/243 [==============================] - 0s 1ms/step - loss: 0.9547 - accuracy: 0.6832 - val_loss: 0.5840 - val_accuracy: 0.8060
# Epoch 4/50
# 243/243 [==============================] - 0s 1ms/step - loss: 0.8247 - accuracy: 0.7297 - val_loss: 0.6498 - val_accuracy: 0.7735
# Epoch 5/50
# 243/243 [==============================] - 0s 1ms/step - loss: 0.7680 - accuracy: 0.7451 - val_loss: 0.4698 - val_accuracy: 0.8359
# Epoch 6/50
# 243/243 [==============================] - 0s 1ms/step - loss: 0.7154 - accuracy: 0.7634 - val_loss: 0.4092 - val_accuracy: 0.8622
# Epoch 7/50
# 243/243 [==============================] - 0s 1ms/step - loss: 0.6739 - accuracy: 0.7724 - val_loss: 0.4316 - val_accuracy: 0.8416
# Epoch 8/50
# 243/243 [==============================] - 0s 1ms/step - loss: 0.6642 - accuracy: 0.7813 - val_loss: 0.3965 - val_accuracy: 0.8720
# Epoch 9/50
# 243/243 [==============================] - 0s 1ms/step - loss: 0.6362 - accuracy: 0.7833 - val_loss: 0.3838 - val_accuracy: 0.8725
# Epoch 10/50
# 243/243 [==============================] - 0s 1ms/step - loss: 0.5889 - accuracy: 0.7981 - val_loss: 0.3461 - val_accuracy: 0.8818
# Epoch 11/50
# 243/243 [==============================] - 0s 1ms/step - loss: 0.5655 - accuracy: 0.8028 - val_loss: 0.3515 - val_accuracy: 0.8767
# Epoch 12/50
# 243/243 [==============================] - 0s 1ms/step - loss: 0.5750 - accuracy: 0.8061 - val_loss: 0.3433 - val_accuracy: 0.8695
# Epoch 13/50
# 243/243 [==============================] - 0s 1ms/step - loss: 0.5578 - accuracy: 0.8105 - val_loss: 0.3508 - val_accuracy: 0.8700
# Epoch 14/50
# 243/243 [==============================] - 0s 1ms/step - loss: 0.5585 - accuracy: 0.8086 - val_loss: 0.3206 - val_accuracy: 0.8865
# Epoch 15/50
# 243/243 [==============================] - 0s 1ms/step - loss: 0.5575 - accuracy: 0.8104 - val_loss: 0.3452 - val_accuracy: 0.8710
# Epoch 16/50
# 243/243 [==============================] - 0s 1ms/step - loss: 0.5220 - accuracy: 0.8231 - val_loss: 0.3392 - val_accuracy: 0.8689
# Epoch 17/50
# 243/243 [==============================] - 0s 1ms/step - loss: 0.5235 - accuracy: 0.8204 - val_loss: 0.3310 - val_accuracy: 0.8824
# Epoch 18/50
# 243/243 [==============================] - 0s 1ms/step - loss: 0.5126 - accuracy: 0.8273 - val_loss: 0.3221 - val_accuracy: 0.8756
# Epoch 19/50
# 243/243 [==============================] - 0s 1ms/step - loss: 0.4933 - accuracy: 0.8299 - val_loss: 0.3336 - val_accuracy: 0.8808
# Epoch 20/50
# 243/243 [==============================] - 0s 1ms/step - loss: 0.5234 - accuracy: 0.8233 - val_loss: 0.3082 - val_accuracy: 0.8906
# Epoch 21/50
# 243/243 [==============================] - 0s 1ms/step - loss: 0.5021 - accuracy: 0.8260 - val_loss: 0.3036 - val_accuracy: 0.8901
# Epoch 22/50
# 243/243 [==============================] - 0s 1ms/step - loss: 0.5067 - accuracy: 0.8255 - val_loss: 0.2974 - val_accuracy: 0.8870
# Epoch 23/50
# 243/243 [==============================] - 0s 1ms/step - loss: 0.4755 - accuracy: 0.8326 - val_loss: 0.2837 - val_accuracy: 0.8968
# Epoch 24/50
# 243/243 [==============================] - 0s 1ms/step - loss: 0.4791 - accuracy: 0.8371 - val_loss: 0.2690 - val_accuracy: 0.8989
# Epoch 25/50
# 243/243 [==============================] - 0s 1ms/step - loss: 0.4709 - accuracy: 0.8388 - val_loss: 0.2783 - val_accuracy: 0.9030
# Epoch 26/50
# 243/243 [==============================] - 0s 1ms/step - loss: 0.4637 - accuracy: 0.8409 - val_loss: 0.2874 - val_accuracy: 0.9004
# Epoch 27/50
# 243/243 [==============================] - 0s 1ms/step - loss: 0.4712 - accuracy: 0.8391 - val_loss: 0.2618 - val_accuracy: 0.9082
# Epoch 28/50
# 243/243 [==============================] - 0s 1ms/step - loss: 0.4709 - accuracy: 0.8415 - val_loss: 0.2855 - val_accuracy: 0.8983
# Epoch 29/50
# 243/243 [==============================] - 0s 1ms/step - loss: 0.4568 - accuracy: 0.8422 - val_loss: 0.2846 - val_accuracy: 0.8989
# Epoch 30/50
# 243/243 [==============================] - 0s 1ms/step - loss: 0.4574 - accuracy: 0.8430 - val_loss: 0.2622 - val_accuracy: 0.9107
# Epoch 31/50
# 243/243 [==============================] - 0s 1ms/step - loss: 0.4448 - accuracy: 0.8496 - val_loss: 0.2590 - val_accuracy: 0.9066
# Epoch 32/50
# 243/243 [==============================] - 0s 1ms/step - loss: 0.4630 - accuracy: 0.8406 - val_loss: 0.2718 - val_accuracy: 0.8978
# Epoch 33/50
# 243/243 [==============================] - 0s 1ms/step - loss: 0.4581 - accuracy: 0.8412 - val_loss: 0.2581 - val_accuracy: 0.9138
# Epoch 34/50
# 243/243 [==============================] - 0s 1ms/step - loss: 0.4363 - accuracy: 0.8524 - val_loss: 0.2657 - val_accuracy: 0.9123
# Epoch 35/50
# 243/243 [==============================] - 0s 1ms/step - loss: 0.4315 - accuracy: 0.8553 - val_loss: 0.2470 - val_accuracy: 0.9118
# Epoch 36/50
# 243/243 [==============================] - 0s 1ms/step - loss: 0.4346 - accuracy: 0.8497 - val_loss: 0.2543 - val_accuracy: 0.9133
# Epoch 37/50
# 243/243 [==============================] - 0s 1ms/step - loss: 0.4309 - accuracy: 0.8509 - val_loss: 0.2644 - val_accuracy: 0.9014
# Epoch 38/50
# 243/243 [==============================] - 0s 1ms/step - loss: 0.4369 - accuracy: 0.8488 - val_loss: 0.2378 - val_accuracy: 0.9107
# Epoch 39/50
# 243/243 [==============================] - 0s 1ms/step - loss: 0.4169 - accuracy: 0.8550 - val_loss: 0.2313 - val_accuracy: 0.9154
# Epoch 40/50
# 243/243 [==============================] - 0s 1ms/step - loss: 0.4079 - accuracy: 0.8656 - val_loss: 0.2369 - val_accuracy: 0.9211
# Epoch 41/50
# 243/243 [==============================] - 0s 1ms/step - loss: 0.4147 - accuracy: 0.8582 - val_loss: 0.2279 - val_accuracy: 0.9174
# Epoch 42/50
# 243/243 [==============================] - 0s 1ms/step - loss: 0.4053 - accuracy: 0.8607 - val_loss: 0.2212 - val_accuracy: 0.9247
# Epoch 43/50
# 243/243 [==============================] - 0s 1ms/step - loss: 0.4092 - accuracy: 0.8607 - val_loss: 0.2277 - val_accuracy: 0.9211
# Epoch 44/50
# 243/243 [==============================] - 0s 1ms/step - loss: 0.3932 - accuracy: 0.8684 - val_loss: 0.2304 - val_accuracy: 0.9149
# Epoch 45/50
# 243/243 [==============================] - 0s 1ms/step - loss: 0.4149 - accuracy: 0.8572 - val_loss: 0.2465 - val_accuracy: 0.9061
# Epoch 46/50
# 243/243 [==============================] - 0s 1ms/step - loss: 0.4171 - accuracy: 0.8563 - val_loss: 0.2240 - val_accuracy: 0.9221
# Epoch 47/50
# 243/243 [==============================] - 0s 1ms/step - loss: 0.4085 - accuracy: 0.8648 - val_loss: 0.2475 - val_accuracy: 0.9123
# Epoch 48/50
# 243/243 [==============================] - 0s 1ms/step - loss: 0.4017 - accuracy: 0.8647 - val_loss: 0.2110 - val_accuracy: 0.9293
# Epoch 49/50
# 243/243 [==============================] - 0s 1ms/step - loss: 0.3873 - accuracy: 0.8680 - val_loss: 0.2206 - val_accuracy: 0.9169
# Epoch 50/50
# 243/243 [==============================] - 0s 1ms/step - loss: 0.3888 - accuracy: 0.8667 - val_loss: 0.2311 - val_accuracy: 0.9118

# %%
y_test_all_encoded = to_categorical(y_test_all.values.ravel(), num_classes=10)

# Evaluate the model
loss, accuracy = model.evaluate(X_test_all_rf, y_test_all_encoded)
print(f"Test Loss: {loss}")
print(f"Test Accuracy: {accuracy}")
# Out:
# 97/97 [==============================] - 0s 464us/step - loss: 0.7321 - accuracy: 0.9061
# Test Loss: 0.7320660352706909
# Test Accuracy: 0.9061488509178162

# %% [markdown]
# ### Impact of Model Using Different Activation Layers

# %%
activation_functions = ['relu', 'sigmoid', 'tanh', 'softmax']  

results = {}

for activation in activation_functions:
    # Define the MLP model architecture with the current activation function
    model = Sequential()
    model.add(Dense(units=300, activation=activation))  # First hidden layer
    model.add(Dense(units=256, activation=activation))
    model.add(Dense(units=32, activation=activation))  # Second hidden layer
    model.add(Dense(10, activation='softmax'))  # Output layer, softmax for multi-class classification
    
    
    model.compile(optimizer=Adam(learning_rate=0.001),
                  loss='categorical_crossentropy',
                  metrics=['accuracy'])
    

    history = model.fit(X_train_rf, y_train_rf, epochs=30, validation_data=(X_test_rf, y_test_rf))
    
   
    scores = model.evaluate(X_test_rf, y_test_rf, verbose=0)
    results[activation] = scores[1]  # using accuracy as  metric
# Out:
# Epoch 1/30
# 243/243 [==============================] - 0s 1ms/step - loss: 1.0740 - accuracy: 0.6712 - val_loss: 0.6489 - val_accuracy: 0.8055
# Epoch 2/30
# 243/243 [==============================] - 0s 1ms/step - loss: 0.5405 - accuracy: 0.8434 - val_loss: 0.4115 - val_accuracy: 0.8844
# Epoch 3/30
# 243/243 [==============================] - 0s 991us/step - loss: 0.4001 - accuracy: 0.8763 - val_loss: 0.3608 - val_accuracy: 0.8829
# Epoch 4/30
# 243/243 [==============================] - 0s 996us/step - loss: 0.3264 - accuracy: 0.8994 - val_loss: 0.3142 - val_accuracy: 0.9009
# Epoch 5/30
# 243/243 [==============================] - 0s 1ms/step - loss: 0.2888 - accuracy: 0.9084 - val_loss: 0.2528 - val_accuracy: 0.9231
# Epoch 6/30
# 243/243 [==============================] - 0s 976us/step - loss: 0.2363 - accuracy: 0.9287 - val_loss: 0.2107 - val_accuracy: 0.9288
# Epoch 7/30
# 243/243 [==============================] - 0s 969us/step - loss: 0.2075 - accuracy: 0.9365 - val_loss: 0.1783 - val_accuracy: 0.9458
# Epoch 8/30
# 243/243 [==============================] - 0s 973us/step - loss: 0.1887 - accuracy: 0.9390 - val_loss: 0.1720 - val_accuracy: 0.9479
# Epoch 9/30
# 243/243 [==============================] - 0s 973us/step - loss: 0.1649 - accuracy: 0.9467 - val_loss: 0.1659 - val_accuracy: 0.9474
# Epoch 10/30
# 243/243 [==============================] - 0s 964us/step - loss: 0.1593 - accuracy: 0.9480 - val_loss: 0.1244 - val_accuracy: 0.9639
# Epoch 11/30
# 243/243 [==============================] - 0s 969us/step - loss: 0.1387 - accuracy: 0.9549 - val_loss: 0.1194 - val_accuracy: 0.9654
# Epoch 12/30
# 243/243 [==============================] - 0s 979us/step - loss: 0.1268 - accuracy: 0.9599 - val_loss: 0.1328 - val_accuracy: 0.9608
# Epoch 13/30
# 243/243 [==============================] - 0s 978us/step - loss: 0.1261 - accuracy: 0.9590 - val_loss: 0.1256 - val_accuracy: 0.9598
# Epoch 14/30
# 243/243 [==============================] - 0s 991us/step - loss: 0.1031 - accuracy: 0.9675 - val_loss: 0.1765 - val_accuracy: 0.9381
# Epoch 15/30
# 243/243 [==============================] - 0s 981us/step - loss: 0.1166 - accuracy: 0.9614 - val_loss: 0.1302 - val_accuracy: 0.9592
# Epoch 16/30
# 243/243 [==============================] - 0s 1ms/step - loss: 0.1015 - accuracy: 0.9663 - val_loss: 0.1030 - val_accuracy: 0.9665
# Epoch 17/30
# 243/243 [==============================] - 0s 994us/step - loss: 0.0894 - accuracy: 0.9711 - val_loss: 0.1049 - val_accuracy: 0.9670
# Epoch 18/30
# 243/243 [==============================] - 0s 996us/step - loss: 0.0877 - accuracy: 0.9706 - val_loss: 0.1207 - val_accuracy: 0.9618
# Epoch 19/30
# 243/243 [==============================] - 0s 973us/step - loss: 0.0881 - accuracy: 0.9714 - val_loss: 0.1029 - val_accuracy: 0.9727
# Epoch 20/30
# 243/243 [==============================] - 0s 1000us/step - loss: 0.0864 - accuracy: 0.9689 - val_loss: 0.1202 - val_accuracy: 0.9613
# Epoch 21/30
# 243/243 [==============================] - 0s 993us/step - loss: 0.0786 - accuracy: 0.9750 - val_loss: 0.1105 - val_accuracy: 0.9670
# Epoch 22/30
# 243/243 [==============================] - 0s 1ms/step - loss: 0.0613 - accuracy: 0.9786 - val_loss: 0.1040 - val_accuracy: 0.9670
# Epoch 23/30
# 243/243 [==============================] - 0s 1000us/step - loss: 0.0680 - accuracy: 0.9778 - val_loss: 0.0847 - val_accuracy: 0.9778
# Epoch 24/30
# 243/243 [==============================] - 0s 986us/step - loss: 0.0599 - accuracy: 0.9791 - val_loss: 0.0974 - val_accuracy: 0.9706
# Epoch 25/30
# 243/243 [==============================] - 0s 991us/step - loss: 0.0645 - accuracy: 0.9768 - val_loss: 0.0732 - val_accuracy: 0.9794
# Epoch 26/30
# 243/243 [==============================] - 0s 989us/step - loss: 0.0523 - accuracy: 0.9831 - val_loss: 0.0903 - val_accuracy: 0.9768
# Epoch 27/30
# 243/243 [==============================] - 0s 1ms/step - loss: 0.0757 - accuracy: 0.9732 - val_loss: 0.0802 - val_accuracy: 0.9768
# Epoch 28/30
# 243/243 [==============================] - 0s 1ms/step - loss: 0.0557 - accuracy: 0.9807 - val_loss: 0.0736 - val_accuracy: 0.9773
# Epoch 29/30
# 243/243 [==============================] - 0s 1ms/step - loss: 0.0469 - accuracy: 0.9844 - val_loss: 0.0754 - val_accuracy: 0.9794
# Epoch 30/30
# 243/243 [==============================] - 0s 1ms/step - loss: 0.0573 - accuracy: 0.9800 - val_loss: 0.1194 - val_accuracy: 0.9628
# Epoch 1/30
# 243/243 [==============================] - 0s 1ms/step - loss: 1.7723 - accuracy: 0.3477 - val_loss: 1.4319 - val_accuracy: 0.5217
# Epoch 2/30
# 243/243 [==============================] - 0s 1ms/step - loss: 1.0833 - accuracy: 0.6947 - val_loss: 0.8307 - val_accuracy: 0.7621
# Epoch 3/30
# 243/243 [==============================] - 0s 1ms/step - loss: 0.7433 - accuracy: 0.7803 - val_loss: 0.6658 - val_accuracy: 0.7900
# Epoch 4/30
# 243/243 [==============================] - 0s 1ms/step - loss: 0.6149 - accuracy: 0.8114 - val_loss: 0.5877 - val_accuracy: 0.8132
# Epoch 5/30
# 243/243 [==============================] - 0s 1ms/step - loss: 0.5323 - accuracy: 0.8326 - val_loss: 0.4786 - val_accuracy: 0.8473
# Epoch 6/30
# 243/243 [==============================] - 0s 1ms/step - loss: 0.4723 - accuracy: 0.8551 - val_loss: 0.4506 - val_accuracy: 0.8586
# Epoch 7/30
# 243/243 [==============================] - 0s 1ms/step - loss: 0.4338 - accuracy: 0.8700 - val_loss: 0.3977 - val_accuracy: 0.8762
# Epoch 8/30
# 243/243 [==============================] - 0s 1ms/step - loss: 0.4068 - accuracy: 0.8762 - val_loss: 0.3851 - val_accuracy: 0.8777
# Epoch 9/30
# 243/243 [==============================] - 0s 1ms/step - loss: 0.3754 - accuracy: 0.8885 - val_loss: 0.3501 - val_accuracy: 0.8906
# Epoch 10/30
# 243/243 [==============================] - 0s 1ms/step - loss: 0.3591 - accuracy: 0.8913 - val_loss: 0.3535 - val_accuracy: 0.8824
# Epoch 11/30
# 243/243 [==============================] - 0s 1ms/step - loss: 0.3486 - accuracy: 0.8913 - val_loss: 0.3255 - val_accuracy: 0.9040
# Epoch 12/30
# 243/243 [==============================] - 0s 1ms/step - loss: 0.3322 - accuracy: 0.8989 - val_loss: 0.3293 - val_accuracy: 0.9035
# Epoch 13/30
# 243/243 [==============================] - 0s 1ms/step - loss: 0.3200 - accuracy: 0.9026 - val_loss: 0.3032 - val_accuracy: 0.9014
# Epoch 14/30
# 243/243 [==============================] - 0s 1ms/step - loss: 0.2985 - accuracy: 0.9101 - val_loss: 0.3325 - val_accuracy: 0.8953
# Epoch 15/30
# 243/243 [==============================] - 0s 1ms/step - loss: 0.2947 - accuracy: 0.9096 - val_loss: 0.2826 - val_accuracy: 0.9164
# Epoch 16/30
# 243/243 [==============================] - 0s 1ms/step - loss: 0.2921 - accuracy: 0.9110 - val_loss: 0.2905 - val_accuracy: 0.9082
# Epoch 17/30
# 243/243 [==============================] - 0s 1ms/step - loss: 0.2778 - accuracy: 0.9164 - val_loss: 0.2599 - val_accuracy: 0.9221
# Epoch 18/30
# 243/243 [==============================] - 0s 1ms/step - loss: 0.2696 - accuracy: 0.9189 - val_loss: 0.2631 - val_accuracy: 0.9185
# Epoch 19/30
# 243/243 [==============================] - 0s 1ms/step - loss: 0.2535 - accuracy: 0.9232 - val_loss: 0.2548 - val_accuracy: 0.9205
# Epoch 20/30
# 243/243 [==============================] - 0s 1ms/step - loss: 0.2503 - accuracy: 0.9229 - val_loss: 0.2545 - val_accuracy: 0.9231
# Epoch 21/30
# 243/243 [==============================] - 0s 1ms/step - loss: 0.2503 - accuracy: 0.9221 - val_loss: 0.2328 - val_accuracy: 0.9329
# Epoch 22/30
# 243/243 [==============================] - 0s 1ms/step - loss: 0.2426 - accuracy: 0.9205 - val_loss: 0.2309 - val_accuracy: 0.9288
# Epoch 23/30
# 243/243 [==============================] - 0s 1ms/step - loss: 0.2299 - accuracy: 0.9287 - val_loss: 0.2220 - val_accuracy: 0.9365
# Epoch 24/30
# 243/243 [==============================] - 0s 1ms/step - loss: 0.2202 - accuracy: 0.9314 - val_loss: 0.2397 - val_accuracy: 0.9272
# Epoch 25/30
# 243/243 [==============================] - 0s 1ms/step - loss: 0.2240 - accuracy: 0.9274 - val_loss: 0.2291 - val_accuracy: 0.9345
# Epoch 26/30
# 243/243 [==============================] - 0s 1ms/step - loss: 0.2175 - accuracy: 0.9350 - val_loss: 0.2156 - val_accuracy: 0.9427
# Epoch 27/30
# 243/243 [==============================] - 0s 1ms/step - loss: 0.2080 - accuracy: 0.9338 - val_loss: 0.2288 - val_accuracy: 0.9226
# Epoch 28/30
# 243/243 [==============================] - 0s 1ms/step - loss: 0.2032 - accuracy: 0.9373 - val_loss: 0.1935 - val_accuracy: 0.9448
# Epoch 29/30
# 243/243 [==============================] - 0s 1ms/step - loss: 0.1959 - accuracy: 0.9376 - val_loss: 0.2112 - val_accuracy: 0.9376
# Epoch 30/30
# 243/243 [==============================] - 0s 1ms/step - loss: 0.1935 - accuracy: 0.9383 - val_loss: 0.2040 - val_accuracy: 0.9407
# Epoch 1/30
# 243/243 [==============================] - 0s 1ms/step - loss: 0.8188 - accuracy: 0.7634 - val_loss: 0.5852 - val_accuracy: 0.8282
# Epoch 2/30
# 243/243 [==============================] - 0s 991us/step - loss: 0.3856 - accuracy: 0.8934 - val_loss: 0.3809 - val_accuracy: 0.8973
# Epoch 3/30
# 243/243 [==============================] - 0s 995us/step - loss: 0.3152 - accuracy: 0.9105 - val_loss: 0.2497 - val_accuracy: 0.9241
# Epoch 4/30
# 243/243 [==============================] - 0s 986us/step - loss: 0.2731 - accuracy: 0.9154 - val_loss: 0.2948 - val_accuracy: 0.9087
# Epoch 5/30
# 243/243 [==============================] - 0s 983us/step - loss: 0.2360 - accuracy: 0.9292 - val_loss: 0.2418 - val_accuracy: 0.9200
# Epoch 6/30
# 243/243 [==============================] - 0s 990us/step - loss: 0.2111 - accuracy: 0.9319 - val_loss: 0.2154 - val_accuracy: 0.9329
# Epoch 7/30
# 243/243 [==============================] - 0s 980us/step - loss: 0.2039 - accuracy: 0.9340 - val_loss: 0.2719 - val_accuracy: 0.9154
# Epoch 8/30
# 243/243 [==============================] - 0s 984us/step - loss: 0.1948 - accuracy: 0.9372 - val_loss: 0.2165 - val_accuracy: 0.9309
# Epoch 9/30
# 243/243 [==============================] - 0s 984us/step - loss: 0.1878 - accuracy: 0.9387 - val_loss: 0.1723 - val_accuracy: 0.9458
# Epoch 10/30
# 243/243 [==============================] - 0s 984us/step - loss: 0.1528 - accuracy: 0.9512 - val_loss: 0.1628 - val_accuracy: 0.9536
# Epoch 11/30
# 243/243 [==============================] - 0s 955us/step - loss: 0.1600 - accuracy: 0.9470 - val_loss: 0.1656 - val_accuracy: 0.9489
# Epoch 12/30
# 243/243 [==============================] - 0s 959us/step - loss: 0.1407 - accuracy: 0.9551 - val_loss: 0.1286 - val_accuracy: 0.9639
# Epoch 13/30
# 243/243 [==============================] - 0s 997us/step - loss: 0.1368 - accuracy: 0.9564 - val_loss: 0.1384 - val_accuracy: 0.9592
# Epoch 14/30
# 243/243 [==============================] - 0s 996us/step - loss: 0.1210 - accuracy: 0.9603 - val_loss: 0.1604 - val_accuracy: 0.9525
# Epoch 15/30
# 243/243 [==============================] - 0s 998us/step - loss: 0.1216 - accuracy: 0.9626 - val_loss: 0.1108 - val_accuracy: 0.9711
# Epoch 16/30
# 243/243 [==============================] - 0s 997us/step - loss: 0.1058 - accuracy: 0.9683 - val_loss: 0.1160 - val_accuracy: 0.9623
# Epoch 17/30
# 243/243 [==============================] - 0s 1ms/step - loss: 0.0971 - accuracy: 0.9707 - val_loss: 0.1163 - val_accuracy: 0.9675
# Epoch 18/30
# 243/243 [==============================] - 0s 1ms/step - loss: 0.1010 - accuracy: 0.9684 - val_loss: 0.1151 - val_accuracy: 0.9701
# Epoch 19/30
# 243/243 [==============================] - 0s 1ms/step - loss: 0.0954 - accuracy: 0.9699 - val_loss: 0.1930 - val_accuracy: 0.9386
# Epoch 20/30
# 243/243 [==============================] - 0s 994us/step - loss: 0.1063 - accuracy: 0.9652 - val_loss: 0.1055 - val_accuracy: 0.9696
# Epoch 21/30
# 243/243 [==============================] - 0s 1000us/step - loss: 0.0799 - accuracy: 0.9754 - val_loss: 0.1196 - val_accuracy: 0.9623
# Epoch 22/30
# 243/243 [==============================] - 0s 1ms/step - loss: 0.0781 - accuracy: 0.9768 - val_loss: 0.1280 - val_accuracy: 0.9628
# Epoch 23/30
# 243/243 [==============================] - 0s 1ms/step - loss: 0.0791 - accuracy: 0.9742 - val_loss: 0.0889 - val_accuracy: 0.9737
# Epoch 24/30
# 243/243 [==============================] - 0s 1ms/step - loss: 0.0669 - accuracy: 0.9805 - val_loss: 0.1151 - val_accuracy: 0.9649
# Epoch 25/30
# 243/243 [==============================] - 0s 997us/step - loss: 0.0894 - accuracy: 0.9706 - val_loss: 0.1175 - val_accuracy: 0.9628
# Epoch 26/30
# 243/243 [==============================] - 0s 1ms/step - loss: 0.0645 - accuracy: 0.9803 - val_loss: 0.1413 - val_accuracy: 0.9551
# Epoch 27/30
# 243/243 [==============================] - 0s 987us/step - loss: 0.0768 - accuracy: 0.9750 - val_loss: 0.0735 - val_accuracy: 0.9794
# Epoch 28/30
# 243/243 [==============================] - 0s 983us/step - loss: 0.0703 - accuracy: 0.9797 - val_loss: 0.0999 - val_accuracy: 0.9690
# Epoch 29/30
# 243/243 [==============================] - 0s 989us/step - loss: 0.0626 - accuracy: 0.9801 - val_loss: 0.1266 - val_accuracy: 0.9608
# Epoch 30/30
# 243/243 [==============================] - 0s 1ms/step - loss: 0.0551 - accuracy: 0.9835 - val_loss: 0.0805 - val_accuracy: 0.9773
# Epoch 1/30
# 243/243 [==============================] - 0s 1ms/step - loss: 2.1641 - accuracy: 0.2166 - val_loss: 2.0581 - val_accuracy: 0.2291
# Epoch 2/30
# 243/243 [==============================] - 0s 1ms/step - loss: 2.0047 - accuracy: 0.2291 - val_loss: 1.9657 - val_accuracy: 0.2291
# Epoch 3/30
# 243/243 [==============================] - 0s 1ms/step - loss: 1.9482 - accuracy: 0.2291 - val_loss: 1.9352 - val_accuracy: 0.2291
# Epoch 4/30
# 243/243 [==============================] - 0s 1ms/step - loss: 1.9286 - accuracy: 0.2276 - val_loss: 1.9208 - val_accuracy: 0.2296
# Epoch 5/30
# 243/243 [==============================] - 0s 1ms/step - loss: 1.9096 - accuracy: 0.2394 - val_loss: 1.8911 - val_accuracy: 0.2482
# Epoch 6/30
# 243/243 [==============================] - 0s 1ms/step - loss: 1.8539 - accuracy: 0.2379 - val_loss: 1.7961 - val_accuracy: 0.2518
# Epoch 7/30
# 243/243 [==============================] - 0s 1ms/step - loss: 1.7257 - accuracy: 0.2933 - val_loss: 1.6379 - val_accuracy: 0.3555
# Epoch 8/30
# 243/243 [==============================] - 0s 1ms/step - loss: 1.5898 - accuracy: 0.3602 - val_loss: 1.5315 - val_accuracy: 0.3596
# Epoch 9/30
# 243/243 [==============================] - 0s 1ms/step - loss: 1.5046 - accuracy: 0.3669 - val_loss: 1.4592 - val_accuracy: 0.3793
# Epoch 10/30
# 243/243 [==============================] - 0s 1ms/step - loss: 1.4566 - accuracy: 0.3724 - val_loss: 1.4228 - val_accuracy: 0.3824
# Epoch 11/30
# 243/243 [==============================] - 0s 1ms/step - loss: 1.4300 - accuracy: 0.3768 - val_loss: 1.4007 - val_accuracy: 0.3854
# Epoch 12/30
# 243/243 [==============================] - 0s 1ms/step - loss: 1.4131 - accuracy: 0.3787 - val_loss: 1.3950 - val_accuracy: 0.3875
# Epoch 13/30
# 243/243 [==============================] - 0s 1ms/step - loss: 1.4037 - accuracy: 0.3768 - val_loss: 1.3797 - val_accuracy: 0.3808
# Epoch 14/30
# 243/243 [==============================] - 0s 1ms/step - loss: 1.3963 - accuracy: 0.3759 - val_loss: 1.3810 - val_accuracy: 0.3782
# Epoch 15/30
# 243/243 [==============================] - 0s 1ms/step - loss: 1.3914 - accuracy: 0.3791 - val_loss: 1.3747 - val_accuracy: 0.3860
# Epoch 16/30
# 243/243 [==============================] - 0s 1ms/step - loss: 1.3894 - accuracy: 0.3762 - val_loss: 1.3653 - val_accuracy: 0.3937
# Epoch 17/30
# 243/243 [==============================] - 0s 1ms/step - loss: 1.3847 - accuracy: 0.3803 - val_loss: 1.3640 - val_accuracy: 0.3968
# Epoch 18/30
# 243/243 [==============================] - 0s 1ms/step - loss: 1.3808 - accuracy: 0.3803 - val_loss: 1.3632 - val_accuracy: 0.3885
# Epoch 19/30
# 243/243 [==============================] - 0s 1ms/step - loss: 1.3805 - accuracy: 0.3764 - val_loss: 1.3574 - val_accuracy: 0.3849
# Epoch 20/30
# 243/243 [==============================] - 0s 1ms/step - loss: 1.3764 - accuracy: 0.3768 - val_loss: 1.3545 - val_accuracy: 0.4180
# Epoch 21/30
# 243/243 [==============================] - 0s 1ms/step - loss: 1.3765 - accuracy: 0.3802 - val_loss: 1.3541 - val_accuracy: 0.3720
# Epoch 22/30
# 243/243 [==============================] - 0s 1ms/step - loss: 1.3732 - accuracy: 0.3760 - val_loss: 1.3584 - val_accuracy: 0.3715
# Epoch 23/30
# 243/243 [==============================] - 0s 1ms/step - loss: 1.3711 - accuracy: 0.3727 - val_loss: 1.3532 - val_accuracy: 0.3901
# Epoch 24/30
# 243/243 [==============================] - 0s 1ms/step - loss: 1.3688 - accuracy: 0.3763 - val_loss: 1.3539 - val_accuracy: 0.3829
# Epoch 25/30
# 243/243 [==============================] - 0s 1ms/step - loss: 1.3672 - accuracy: 0.3818 - val_loss: 1.3496 - val_accuracy: 0.3865
# Epoch 26/30
# 243/243 [==============================] - 0s 1ms/step - loss: 1.3639 - accuracy: 0.3851 - val_loss: 1.3570 - val_accuracy: 0.3829
# Epoch 27/30
# 243/243 [==============================] - 0s 1ms/step - loss: 1.3618 - accuracy: 0.3747 - val_loss: 1.3440 - val_accuracy: 0.3953
# Epoch 28/30
# 243/243 [==============================] - 0s 1ms/step - loss: 1.3579 - accuracy: 0.3865 - val_loss: 1.3424 - val_accuracy: 0.3994
# Epoch 29/30
# 243/243 [==============================] - 0s 1ms/step - loss: 1.3509 - accuracy: 0.3820 - val_loss: 1.3342 - val_accuracy: 0.3947
# Epoch 30/30
# 243/243 [==============================] - 0s 1ms/step - loss: 1.3406 - accuracy: 0.3949 - val_loss: 1.3388 - val_accuracy: 0.3885

# %%
plt.figure(figsize=(10, 6))
bars = plt.bar(results.keys(), results.values())

for bar in bars:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, yval, round(yval, 2), ha='center', va='bottom')

plt.xlabel('Activation Functions')
plt.ylabel('Accuracy')
plt.title('Comparison of Activation Functions')
plt.show()

# %% [markdown]
# We see that though Relu is the best activation layer in terms of accuracy Relu, sigmoid and tanh have close accurcay.
# This is strange as Sigmoid id ususally used for binary classification and wouldn't be thought to work well with multiclass classification. This also indicates that using Relu, sigmoid or tanh doesnt bring about a big difference in model accuracy.
